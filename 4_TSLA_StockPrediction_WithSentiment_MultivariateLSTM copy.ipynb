# %%
import datetime
import numpy
import ray
import torch
#
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8,4)
plt.rcParams['axes.grid'] = True
plt.rcParams.update({'font.size': 12})
import pandas as pd
import seaborn as sns
import torch.nn as nn
import yfinance as yf
#
from sklearn.preprocessing import MinMaxScaler
from ray import train, tune
from torch.autograd import Variable

# %%
# loading sentiment scores
sentiment_scores_df = pd.read_csv('daily-avg-sentiment-scores.csv')
sentiment_scores_df = sentiment_scores_df.set_index('date')
sentiment_scores_df = pd.DataFrame(sentiment_scores_df)
sentiment_scores_df.index = pd.to_datetime(sentiment_scores_df.index)
sentiment_scores_df
# Out:
#             sentiment_score
# date
# 2020-01-01         0.154961
# 2020-01-02         0.161528
# 2020-01-03         0.128297
# 2020-01-04         0.144796
# 2020-01-05         0.132267
# ...                     ...
# 2020-12-28         0.151300
# 2020-12-29         0.118094
# 2020-12-30         0.172049
# 2020-12-31         0.137480
# 2021-01-01         0.211227
#
# [367 rows x 1 columns]

# %%
# load dataset
start_time_all = datetime.datetime(2020, 1, 1).strftime('%Y-%m-%d') # 2020-01-01
end_time_train = datetime.datetime(2020, 9, 30).strftime('%Y-%m-%d') # 2020-09-30
start_time_val = datetime.datetime(2020, 10, 1).strftime('%Y-%m-%d') # 2020-10-01
end_time_all = datetime.datetime(2020, 12, 31).strftime('%Y-%m-%d') # 2020-12-31

# loading Tesla, Inc. (TSLA) stock price data from Yahoo Finance
tsla_price_df = yf.download('TSLA', start=start_time_all, end=end_time_all)
tsla_price_df.index = pd.to_datetime(tsla_price_df.index)
tsla_price_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2020-12-23  210.733337  217.166672  207.523331  215.326660  215.326660
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
#
#                Volume
# Date
# 2020-01-02  142981500
# 2020-01-03  266677500
# 2020-01-06  151995000
# 2020-01-07  268231500
# 2020-01-08  467164500
# ...               ...
# 2020-12-23   99519000
# 2020-12-24   68596800
# 2020-12-28   96835800
# 2020-12-29   68732400
# 2020-12-30  128538000
#
# [252 rows x 6 columns]

# %%
# adding sentiment scores to stock price data
tsla_price_df = pd.merge(tsla_price_df, sentiment_scores_df, left_index=True, right_index=True)
tsla_price_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2020-12-23  210.733337  217.166672  207.523331  215.326660  215.326660
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
#
#                Volume  sentiment_score
# 2020-01-02  142981500         0.161528
# 2020-01-03  266677500         0.128297
# 2020-01-06  151995000         0.117547
# 2020-01-07  268231500         0.104325
# 2020-01-08  467164500         0.123884
# ...               ...              ...
# 2020-12-23   99519000         0.158640
# 2020-12-24   68596800         0.165211
# 2020-12-28   96835800         0.151300
# 2020-12-29   68732400         0.118094
# 2020-12-30  128538000         0.172049
#
# [252 rows x 7 columns]

# %%
# adding daily returns to stock price data
tsla_price_df['Return'] = tsla_price_df['Adj Close'].pct_change()
# calculating correlation between daily returns and sentiment scores
tsla_price_df['Return'][1:].corr(tsla_price_df['sentiment_score'][1:])
# Out:
# 0.009413099458638857

# %%
# plotting correlation between daily returns and sentiment scores
sns.regplot(x=tsla_price_df['Return'][1:], y=tsla_price_df['sentiment_score'][1:], color='g')
plt.title('Correlation between Daily Returns and Sentiment Scores')
plt.show()

# %%
# features (High price, Low price, Open price, Close price, Volume, Sentiment)
tsla_price_df = tsla_price_df.dropna()
tsla_price_df = tsla_price_df.drop(columns=['Return'])
X = tsla_price_df.iloc[:, tsla_price_df.columns != 'Adj Close']
# response (Adj Close price)
y = tsla_price_df.loc[:, 'Adj Close']

# %%
# plotting TSLA Adj Close price from 2020-01-01 to 2020-12-31
plt.plot(y)
plt.xlabel('\nDate')
plt.ylabel('Adj Close Price\n')
plt.title('TSLA Adj Close Price')
plt.show()

# %%
# train/test splitting
n_split = 189 # where to split training and validation datasets

# normalizing datasets (this introduces lookahead bias, to be fixed)
scaler = MinMaxScaler()
X_norm = scaler.fit_transform(X)
y_norm = scaler.fit_transform(y.values.reshape(1, -1).reshape(-1, 1))

# training using Jan - Sep data
# validating trained model using Oct - Dec data
X_train = X_norm[:n_split, :]
y_train = y_norm[:n_split, :]

print('Training Set Shape ', X_train.shape, y_train.shape)
# Out:
# Training Set Shape  (189, 6) (189, 1)

# %%
# converting data to tensors
X_train_tensors = Variable(torch.Tensor(X_train))
y_train_tensors = Variable(torch.Tensor(y_train))

X_val_tensors = Variable(torch.Tensor(X_norm))
y_true = numpy.array(y).reshape(-1, 1)

# reshaping X dataset
X_train_tensors = torch.reshape(X_train_tensors, (X_train_tensors.shape[0], 
                                                  1, X_train_tensors.shape[1]))
X_val_tensors = torch.reshape(X_val_tensors, (X_val_tensors.shape[0], 
                                              1, X_val_tensors.shape[1]))

print('Training Set Shape   ', X_train_tensors.shape, y_train_tensors.shape)
print('Validation Set Shape ', X_val_tensors.shape, y_true.shape)
# Out:
# Training Set Shape    torch.Size([189, 1, 6]) torch.Size([189, 1])
# Validation Set Shape  torch.Size([251, 1, 6]) (251, 1)

# %%
# LSTM
# selecting gpu
device = torch.device('cpu')

# %%
class LSTM_model(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM_model, self).__init__()
        self.input_size = input_size # number of features
        self.hidden_size = hidden_size # number of features in hidden state
        self.num_layers = num_layers # number of stacked LSTM layers
        self.num_classes = num_classes # number of output classes
    
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, 
                            num_layers=num_layers, batch_first=True) # LSTM layer
        self.fc = nn.Linear(hidden_size, num_classes) # fully connected last layer

    def forward(self, x):
        h0 = Variable(torch.zeros(self.num_layers, x.size(0), 
                                  self.hidden_size)).to(device) # hidden state
        c0 = Variable(torch.zeros(self.num_layers, x.size(0), 
                                  self.hidden_size)).to(device) # internal state
        # propagating input through LSTM
        out, _ = self.lstm(x, (h0, c0)) # out: tensor of shape (seq_length, batch_size, hidden_size)
        # decoding hidden state of last time step
        out = self.fc(out[:, -1, :])
        return out

# %%
# function for calculating MSE (Mean Squared Error)
def calc_mse(y_true, y_hat):
    mse = float(sum((y_true - y_hat) * (y_true - y_hat)) / len(y_hat))
    return mse

# %%
# function for fitting and evaluating model using different hyperparameters
def model_fit_eval(config=None, best_config=None, save_model_state=False):
    if best_config is None:
        hidden_size = config['hidden_size']
        num_layers = config['num_layers']
        learning_rate = config['learning_rate']
        # learning rate controls how much to change model in response to estm error each time model weights are updated
        num_epochs = config['num_epochs']
    else:
        hidden_size = best_config['hidden_size']
        num_layers = best_config['num_layers']
        learning_rate = best_config['learning_rate']
        num_epochs = best_config['num_epochs']

    input_size = len(X.columns)
    num_classes = 1
    
    model = LSTM_model(input_size, hidden_size, num_layers, num_classes).to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) # adam optimizer
    # algorithms/methods to change attributes of neural network such as weights and learning rate to reduce losses

    loss_function = torch.nn.MSELoss() # mean-squared error of regression
    # loss function measures how bad model performs: high loss -> low accuracy

    for epoch in range(num_epochs + 1):
        outputs = model.forward(X_train_tensors.to(device)) # forward pass
        optimizer.zero_grad() # calculating gradient, manually setting to 0
        loss = loss_function(outputs, y_train_tensors.to(device)) # obtaining loss
        loss.backward() # calculating loss of loss function
        optimizer.step() # improving from loss, i.e. backprop
        if best_config is not None:
            if epoch % 1000 == 0:
                print(f'Epoch: {epoch}, Loss: {loss.item():.4f}')
    
    # saving model state
    if save_model_state:
        torch.save(model.state_dict(), '1-model-state.pth')

    # loading model state
    # model = LSTM_model(*args, **kwargs)
    # model.load_state_dict(torch.load(PATH))
    # model.eval()
    
    # predicting response from model
    y_hat = model(X_val_tensors.to(device)) # forward pass
    y_hat = y_hat.data.detach().cpu().numpy() # numpy conversion
    y_hat = scaler.inverse_transform(y_hat) # inverse transformation

    if best_config is None:
        mse = calc_mse(y_true, y_hat)
        train.report({'mse': mse})
    else:
        return y_hat

# %%
# starting ray runtime
ray.init()
# Out:
# 2023-10-12 22:06:21,456	INFO worker.py:1642 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.8.10', ray_version='2.7.1', ray_commit='9f07c12615958c3af3760604f6dcacc4b3758a47', protocol_version=None)

# %%
# checking available resources
ray.cluster_resources()
# Out:
# {'CPU': 8.0,
#  'object_store_memory': 5658110361.0,
#  'node:127.0.0.1': 1.0,
#  'memory': 11316220724.0,
#  'node:__internal_head__': 1.0}

# %%
# using grid search to get best hyperparameters
analysis = tune.run(
    model_fit_eval, 
    config={'hidden_size': tune.grid_search([2, 3, 5]), 
            'learning_rate': tune.grid_search([0.0005, 0.001, 0.002]), 
            'num_epochs': tune.grid_search([2000, 4000, 8000]), 
            'num_layers': tune.grid_search([1, 2, 4])}, 
    resources_per_trial={'cpu': 2, 'gpu': 0}) # leveraging all resources
# Out:
# 2023-10-12 22:06:27,363	INFO tune.py:645 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-10-12 22:27:36</td></tr>
# <tr><td>Running for: </td><td>00:21:08.78        </td></tr>
# <tr><td>Memory:      </td><td>13.8/31.6 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 2.0/8 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc            </th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  num_epochs</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">      mse</th></tr>
# </thead>
# <tbody>
# <tr><td>model_fit_eval_d3967_00000</td><td>TERMINATED</td><td>127.0.0.1:5596 </td><td style="text-align: right;">            2</td><td style="text-align: right;">         0.0005</td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         23.2922</td><td style="text-align: right;">112.314  </td></tr>
# <tr><td>model_fit_eval_d3967_00001</td><td>TERMINATED</td><td>127.0.0.1:13668</td><td style="text-align: right;">            3</td><td style="text-align: right;">         0.0005</td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         21.7518</td><td style="text-align: right;">187.109  </td></tr>
# <tr><td>model_fit_eval_d3967_00002</td><td>TERMINATED</td><td>127.0.0.1:12960</td><td style="text-align: right;">            5</td><td style="text-align: right;">         0.0005</td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         21.6642</td><td style="text-align: right;"> 52.0598 </td></tr>
# <tr><td>model_fit_eval_d3967_00003</td><td>TERMINATED</td><td>127.0.0.1:18812</td><td style="text-align: right;">            2</td><td style="text-align: right;">         0.001 </td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         23.6519</td><td style="text-align: right;">166.585  </td></tr>
# <tr><td>model_fit_eval_d3967_00004</td><td>TERMINATED</td><td>127.0.0.1:13668</td><td style="text-align: right;">            3</td><td style="text-align: right;">         0.001 </td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         14.1914</td><td style="text-align: right;"> 29.8386 </td></tr>
# <tr><td>model_fit_eval_d3967_00005</td><td>TERMINATED</td><td>127.0.0.1:5596 </td><td style="text-align: right;">            5</td><td style="text-align: right;">         0.001 </td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         14.0541</td><td style="text-align: right;"> 55.7027 </td></tr>
# <tr><td>model_fit_eval_d3967_00006</td><td>TERMINATED</td><td>127.0.0.1:18812</td><td style="text-align: right;">            2</td><td style="text-align: right;">         0.002 </td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         16.5464</td><td style="text-align: right;"> 51.2934 </td></tr>
# <tr><td>model_fit_eval_d3967_00007</td><td>TERMINATED</td><td>127.0.0.1:13668</td><td style="text-align: right;">            3</td><td style="text-align: right;">         0.002 </td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         10.5315</td><td style="text-align: right;"> 50.6821 </td></tr>
# <tr><td>model_fit_eval_d3967_00008</td><td>TERMINATED</td><td>127.0.0.1:5596 </td><td style="text-align: right;">            5</td><td style="text-align: right;">         0.002 </td><td style="text-align: right;">        2000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         12.5175</td><td style="text-align: right;"> 17.8576 </td></tr>
# <tr><td>model_fit_eval_d3967_00009</td><td>TERMINATED</td><td>127.0.0.1:18812</td><td style="text-align: right;">            2</td><td style="text-align: right;">         0.0005</td><td style="text-align: right;">        4000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         25.328 </td><td style="text-align: right;">441.514  </td></tr>
# <tr><td>model_fit_eval_d3967_00010</td><td>TERMINATED</td><td>127.0.0.1:12960</td><td style="text-align: right;">            3</td><td style="text-align: right;">         0.0005</td><td style="text-align: right;">        4000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         27.7592</td><td style="text-align: right;"> 71.54   </td></tr>
# <tr><td>model_fit_eval_d3967_00011</td><td>TERMINATED</td><td>127.0.0.1:13668</td><td style="text-align: right;">            5</td><td style="text-align: right;">         0.0005</td><td style="text-align: right;">        4000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         23.2493</td><td style="text-align: right;"> 29.3806 </td></tr>
# <tr><td>model_fit_eval_d3967_00012</td><td>TERMINATED</td><td>127.0.0.1:12960</td><td style="text-align: right;">            2</td><td style="text-align: right;">         0.001 </td><td style="text-align: right;">        4000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         23.7914</td><td style="text-align: right;">167.994  </td></tr>
# <tr><td>model_fit_eval_d3967_00013</td><td>TERMINATED</td><td>127.0.0.1:5596 </td><td style="text-align: right;">            3</td><td style="text-align: right;">         0.001 </td><td style="text-align: right;">        4000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         22.3518</td><td style="text-align: right;"> 60.6888 </td></tr>
# <tr><td>model_fit_eval_d3967_00014</td><td>TERMINATED</td><td>127.0.0.1:13668</td><td style="text-align: right;">            5</td><td style="text-align: right;">         0.001 </td><td style="text-align: right;">        4000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         24.877 </td><td style="text-align: right;"> 41.1973 </td></tr>
# <tr><td>model_fit_eval_d3967_00015</td><td>TERMINATED</td><td>127.0.0.1:5596 </td><td style="text-align: right;">            2</td><td style="text-align: right;">         0.002 </td><td style="text-align: right;">        4000</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         26.0706</td><td style="text-align: right;">100.848  </td></tr>
# <tr><td>model_fit_eval_d3967_00016</td><td>TERMINATED</td><td>127.0.0.1:12960</td><td style="text
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                </th><th style="text-align: right;">      mse</th></tr>
# </thead>
# <tbody>
# <tr><td>model_fit_eval_d3967_00000</td><td style="text-align: right;">112.314  </td></tr>
# <tr><td>model_fit_eval_d3967_00001</td><td style="text-align: right;">187.109  </td></tr>
# <tr><td>model_fit_eval_d3967_00002</td><td style="text-align: right;"> 52.0598 </td></tr>
# <tr><td>model_fit_eval_d3967_00003</td><td style="text-align: right;">166.585  </td></tr>
# <tr><td>model_fit_eval_d3967_00004</td><td style="text-align: right;"> 29.8386 </td></tr>
# <tr><td>model_fit_eval_d3967_00005</td><td style="text-align: right;"> 55.7027 </td></tr>
# <tr><td>model_fit_eval_d3967_00006</td><td style="text-align: right;"> 51.2934 </td></tr>
# <tr><td>model_fit_eval_d3967_00007</td><td style="text-align: right;"> 50.6821 </td></tr>
# <tr><td>model_fit_eval_d3967_00008</td><td style="text-align: right;"> 17.8576 </td></tr>
# <tr><td>model_fit_eval_d3967_00009</td><td style="text-align: right;">441.514  </td></tr>
# <tr><td>model_fit_eval_d3967_00010</td><td style="text-align: right;"> 71.54   </td></tr>
# <tr><td>model_fit_eval_d3967_00011</td><td style="text-align: right;"> 29.3806 </td></tr>
# <tr><td>model_fit_eval_d3967_00012</td><td style="text-align: right;">167.994  </td></tr>
# <tr><td>model_fit_eval_d3967_00013</td><td style="text-align: right;"> 60.6888 </td></tr>
# <tr><td>model_fit_eval_d3967_00014</td><td style="text-align: right;"> 41.1973 </td></tr>
# <tr><td>model_fit_eval_d3967_00015</td><td style="text-align: right;">100.848  </td></tr>
# <tr><td>model_fit_eval_d3967_00016</td><td style="text-align: right;"> 42.8609 </td></tr>
# <tr><td>model_fit_eval_d3967_00017</td><td style="text-align: right;"> 16.0293 </td></tr>
# <tr><td>model_fit_eval_d3967_00018</td><td style="text-align: right;"> 27.3959 </td></tr>
# <tr><td>model_fit_eval_d3967_00019</td><td style="text-align: right;"> 41.9339 </td></tr>
# <tr><td>model_fit_eval_d3967_00020</td><td style="text-align: right;"> 13.2336 </td></tr>
# <tr><td>model_fit_eval_d3967_00021</td><td style="text-align: right;"> 49.3534 </td></tr>
# <tr><td>model_fit_eval_d3967_00022</td><td style="text-align: right;"> 22.2451 </td></tr>
# <tr><td>model_fit_eval_d3967_00023</td><td style="text-align: right;"> 15.8222 </td></tr>
# <tr><td>model_fit_eval_d3967_00024</td><td style="text-align: right;"> 13.2593 </td></tr>
# <tr><td>model_fit_eval_d3967_00025</td><td style="text-align: right;">  4.9417 </td></tr>
# <tr><td>model_fit_eval_d3967_00026</td><td style="text-align: right;">  2.44102</td></tr>
# <tr><td>model_fit_eval_d3967_00027</td><td style="text-align: right;">344.821  </td></tr>
# <tr><td>model_fit_eval_d3967_00028</td><td style="text-align: right;">216.348  </td></tr>
# <tr><td>model_fit_eval_d3967_00029</td><td style="text-align: right;">112      </td></tr>
# <tr><td>model_fit_eval_d3967_00030</td><td style="text-align: right;">223.326  </td></tr>
# <tr><td>model_fit_eval_d3967_00031</td><td style="text-align: right;">161.069  </td></tr>
# <tr><td>model_fit_eval_d3967_00032</td><td style="text-align: right;"> 30.0057 </td></tr>
# <tr><td>model_fit_eval_d3967_00033</td><td style="text-align: right;"> 69.7398 </td></tr>
# <tr><td>model_fit_eval_d3967_00034</td><td style="text-align: right;"> 85.5818 </td></tr>
# <tr><td>model_fit_eval_d3967_00035</td><td style="text-align: right;"> 22.0246 </td></tr>
# <tr><td>model_fit_eval_d3967_00036</td><td style="text-align: right;"> 93.8267 </td></tr>
# <tr><td>model_fit_eval_d3967_00037</td><td style="text-align: right;">136.972  </td></tr>
# <tr><td>model_fit_eval_d3967_00038</td><td style="text-align: right;"> 39.6801 </td></tr>
# <tr><td>model_fit_eval_d3967_00039</td><td style="text-align: right;"> 21.5447 </td></tr>
# <tr><td>model_fit_eval_d3967_00040</td><td style="text-align: right;"> 30.6818 </td></tr>
# <tr><td>model_fit_eval_d3967_00041</td><td style="text-align: right;"> 72.8547 </td></tr>
# <tr><td>model_fit_eval_d3967_00042</td><td style="text-align: right;"> 81.5009 </td></tr>
# <tr><td>model_fit_eval_d3967_00043</td><td style="text-align: right;"> 34.1674 </td></tr>
# <tr><td>model_fit_eval_d3967_00044</td><td style="text-align: right;"> 28.582  </td></tr>
# <tr><td>model_fit_eval_d3967_00045</td><td style="text-align: right;"> 68.4731 </td></tr>
# <tr><td>model_fit_eval_d3967_00046</td><td style="text-align: right;"> 12.9915 </td></tr>
# <tr><td>model_fit_eval_d3967_00047</td><td style="text-align: right;">  3.4861 </td></tr>
# <tr><td>model_fit_eval_d3967_00048</td><td style="text-align: right;"> 36.332  </td></tr>
# <tr><td>model_fit_eval_d3967_00049</td><td style="text-align: right;"> 42.2772 </td></tr>
# <tr><td>model_fit_eval_d3967_00050</td><td style="text-align: right;"> 14.638  </td></tr>
# <tr><td>model_fit_eval_d3967_00051</td><td style="text-align: right;"> 11.9676 </td></tr>
# <tr><td>model_fit_eval_d3967_00052</td><td style="text-align: right;"> 11.1582 </td></tr>
# <tr><td>model_fit_eval_d3967_00053</td><td style="text-align: right;"> 16.4832 </td></tr>
# <tr><td>model_fit_eval_d3967_00054</td><td style="text-align: right;">842.141  </td></tr>
# <tr><td>model_fit_eval_d3967_00055</td><td style="text-align: right;">566.94   </td></tr>
# <tr><td>model_fit_eval_d3967_00056</td><td style="text-align: right;"> 64.9435 </td></tr>
# <tr><td>model_fit_eval_d3967_00057</td><td style="text-align: right;"> 49.867  </td></tr>
# <tr><td>model_fit_eval_d3967_00058</td><td style="text-align: right;">243.95   </td></tr>
# <tr><td>model_fit_eval_d3967_00059</td><td style="text-align: right;"> 47.9546 </td></tr>
# <tr><td>model_fit_eval_d3967_00060</td><td style="text-align: right;">136.551  </td></tr>
# <tr><td>model_fit_eval_d3967_00061</td><td style="text-align: right;"> 74.5826 </td></tr>
# <tr><td>model_fit_eval_d3967_00062</td><td style="text-align: right;"> 23.3388 </td></tr>
# <tr><td>model_fit_eval_d3967_00063</td><td style="text-align: right;">212.588  </td></tr>
# <tr><td>model_fit_eval_d3967_00064</td><td style="text-align: right;">157.695  </td></tr>
# <tr><td>model_fit_eval_d3967_00065</td><td style="text-align: right;">125.868  </td></tr>
# <tr><td>model_fit_eval_d3967_00066</td><td style="text-align: right;">137.548  </td></tr>
# <tr><td>model_fit_eval_d3967_00067</td><td style="text-align: right;"> 70.8953 </td></tr>
# <tr><td>model_fit_eval_d3967_00068</td><td style="text-align: right;"> 14.1483 </td></tr>
# <tr><td>model_fit_eval_d3967_00069</td><td style="text-align: right;">131.413  </td></tr>
# <tr><td>model_fit_eval_d3967_00070</td><td style="text-align: right;"> 72.4933 </td></tr>
# <tr><td>model_fit_eval_d3967_00071</td><td style="text-align: right;"> 39.733  </td></tr>
# <tr><td>model_fit_eval_d3967_00072</td><td style="text-align: right;">100.482  </td></tr>
# <tr><td>model_fit_eval_d3967_00073</td><td style="text-align: right;"> 43.2744 </td></tr>
# <tr><td>model_fit_eval_d3967_00074</td><td style="text-align: right;"> 46.193  </td></tr>
# <tr><td>model_fit_eval_d3967_00075</td><td style="text-align: right;"> 42.8235 </td></tr>
# <tr><td>model_fit_eval_d3967_00076</td><td style="text-align: right;"> 14.4562 </td></tr>
# <tr><td>model_fit_eval_d3967_00077</td><td style="text-align: right;"> 23.9356 </td></tr>
# <tr><td>model_fit_eval_d3967_00078</td><td style="text-align: right;"> 67.1488 </td></tr>
# <tr><td>model_fit_eval_d3967_00079</td><td style="text-align: right;"> 26.1114 </td></tr>
# <tr><td>model_fit_eval_d3967_00080</td><td style="text-align: right;"> 15.0436 </td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2023-10-12 22:07:53,491	WARNING util.py:315 -- The `on_step_begin` operation took 15.654 s, which may be a performance bottleneck.
# 2023-10-12 22:08:20,680	WARNING util.py:315 -- The `on_step_begin` operation took 17.045 s, which may be a performance bottleneck.
# 2023-10-12 22:08:46,368	WARNING util.py:315 -- The `on_step_begin` operation took 15.567 s, which may be a performance bottleneck.
# 2023-10-12 22:09:10,397	WARNING util.py:315 -- The `on_step_begin` operation took 3.787 s, which may be a performance bottleneck.
# 2023-10-12 22:09:40,273	WARNING util.py:315 -- The `on_step_begin` operation took 19.825 s, which may be a performance bottleneck.
# 2023-10-12 22:10:06,419	WARNING util.py:315 -- The `on_step_begin` operation took 16.125 s, which may be a performance bottleneck.
# 2023-10-12 22:10:20,361	WARNING util.py:315 -- The `on_step_begin` operation took 3.853 s, which may be a performance bottleneck.
# 2023-10-12 22:10:33,367	WARNING util.py:315 -- The `on_step_begin` operation took 2.841 s, which may be a performance bottleneck.
# 2023-10-12 22:10:50,445	WARNING util.py:315 -- The `on_step_begin` operation took 6.998 s, which may be a performance bottleneck.
# 2023-10-12 22:12:06,422	WARNING util.py:315 -- The `on_step_begin` operation took 25.482 s, which may be a performance bottleneck.
# 2023-10-12 22:12:43,396	WARNING util.py:315 -- The `on_step_begin` operation took 26.853 s, which may be a performance bottleneck.
# 2023-10-12 22:13:22,424	WARNING util.py:315 -- The `on_step_begin` operation took 28.877 s, which may be a performance bottleneck.
# 2023-10-12 22:14:09,924	WARNING util.py:315 -- The `on_step_begin` operation took 37.395 s, which may be a performance bottleneck.
# 2023-10-12 22:15:18,787	WARNING util.py:315 -- The `on_step_begin` operation took 23.181 s, which may be a performance bottleneck.
# 2023-10-12 22:15:43,129	WARNING util.py:315 -- The `on_step_begin` operation took 14.202 s, which may be a performance bottleneck.
# 2023-10-12 22:16:31,245	WARNING util.py:315 -- The `on_step_begin` operation took 28.012 s, which may be a performance bottleneck.
# 2023-10-12 22:16:44,417	WARNING util.py:315 -- The `on_step_begin` operation took 3.035 s, which may be a performance bottleneck.
# 2023-10-12 22:17:14,847	WARNING util.py:315 -- The `on_step_begin` operation took 20.334 s, which may be a performance bottleneck.
# 2023-10-12 22:18:06,245	WARNING util.py:315 -- The `on_step_begin` operation took 21.189 s, which may be a performance bottleneck.
# 2023-10-12 22:18:21,678	WARNING util.py:315 -- The `on_step_begin` operation took 5.381 s, which may be a performance bottleneck.
# 2023-10-12 22:18:38,545	WARNING util.py:315 -- The `on_step_begin` operation took 6.819 s, which may be a performance bottleneck.
# 2023-10-12 22:19:10,020	WARNING util.py:315 -- The `on_step_begin` operation took 21.425 s, which may be a performance bottleneck.
# 2023-10-12 22:19:25,613	WARNING util.py:315 -- The `on_step_begin` operation took 5.430 s, which may be a performance bottleneck.
# 2023-10-12 22:20:06,887	WARNING util.py:315 -- The `on_step_begin` operation took 31.177 s, which may be a performance bottleneck.
# 2023-10-12 22:20:44,862	WARNING util.py:315 -- The `on_step_begin` operation took 27.954 s, which may be a performance bottleneck.
# 2023-10-12 22:21:28,112	WARNING util.py:315 -- The `on_step_begin` operation took 33.216 s, which may be a performance bottleneck.
# 2023-10-12 22:22:15,612	WARNING util.py:315 -- The `on_step_begin` operation took 37.307 s, which may be a performance bottleneck.
# 2023-10-12 22:23:04,297	WARNING util.py:315 -- The `on_step_begin` operation took 38.663 s, which may be a performance bottleneck.
# 2023-10-12 22:23:56,463	WARNING util.py:315 -- The `on_step_begin` operation took 22.037 s, which may be a performance bottleneck.
# 2023-10-12 22:24:40,485	WARNING util.py:315 -- The `on_step_begin` operation took 33.860 s, which may be a performance bottleneck.
# 2023-10-12 22:25:36,308	WARNING util.py:315 -- The `on_step_begin` operation took 45.729 s, which may be a performance bottleneck.
# 2023-10-12 22:27:36,283	INFO tune.py:1143 -- Total run time: 1268.92 seconds (1268.75 seconds for the tuning loop).

# %%
# # visualizing hyperparameter tuning results
# %load_ext tensorboard
# %tensorboard --logdir ~/ray_results

# %%
# best hyperparameters
best_trial = analysis.get_best_trial(metric='mse', mode='min', scope='all')
min_mse = best_trial.metric_analysis['mse']['avg']
print(f'Min MSE: {min_mse}')
best_trial_config = best_trial.config
print(f'Best trial config: {best_trial_config}')
# Out:
# Min MSE: 2.4410157939634094
# Best trial config: {'hidden_size': 5, 'learning_rate': 0.002, 'num_epochs': 8000, 'num_layers': 1}

# %%
# training model using best hyperparameters
best_trial_config['num_epochs'] = 10000 # increasing num of epochs
y_hat = model_fit_eval(best_config=best_trial_config, save_model_state=True)
# Out:
# Epoch: 0, Loss: 0.0597
# Epoch: 1000, Loss: 0.0001
# Epoch: 2000, Loss: 0.0000
# Epoch: 3000, Loss: 0.0000
# Epoch: 4000, Loss: 0.0000
# Epoch: 5000, Loss: 0.0000
# Epoch: 6000, Loss: 0.0000
# Epoch: 7000, Loss: 0.0000
# Epoch: 8000, Loss: 0.0000
# Epoch: 9000, Loss: 0.0000
# Epoch: 10000, Loss: 0.0000

# %%
# shutting down ray runtime
ray.shutdown()

# %%
# function for plotting actual and predicted Adj Close price
def plt_graph(period, val_line=False):
    # plotting actual Adj Close price
    plt.plot(tsla_price_df.index, y_true, label='Actual Price')
    # plotting predicted Adj Close price
    plt.plot(tsla_price_df.index, y_hat, label='Pred Price')
    if val_line:
        plt.axvline(x=pd.to_datetime(start_time_val), c='r', linestyle='--')
    plt.xlabel('Date')
    plt.ylabel('Adj Close Price')
    plt.title(f'{period} Period')
    plt.legend()
    plt.show()

# %%
# plotting all period
period = 'All'
plt_graph(period, True)

# %%
period = 'Validation'
mse = calc_mse(y_true[n_split:], y_hat[n_split:])
print(f'MSE ({period}): {mse}')
# 24, 8
# Out:
# MSE (Validation): 8.94441137209745
